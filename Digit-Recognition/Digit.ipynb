# %% [markdown]
# ## Imports

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# %% [markdown]
# ## Load Images with Keras
#
# Use tf.keras.preprocessing.image_dataset_from_directory to automatically load and split your data:

# %%
data_dir = "./DIDA_30K_String_Digit_Images/"

batch_size = 32
img_size = (64, 64)  # or adapt based on actual image resolution

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="training",
    seed=42,
    image_size=img_size,
    batch_size=batch_size
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="validation",
    seed=42,
    image_size=img_size,
    batch_size=batch_size
)
# Out:
# Found 30247 files belonging to 1 classes.
# Using 24198 files for training.
# Found 30247 files belonging to 1 classes.
# Using 6049 files for validation.

# %% [markdown]
# ## Define a Convolutional Neural Network
#
# Here's a straightforward CNN inspired by the DIGITNET-rec architecture:

# %%
num_classes = 10

model = models.Sequential([
    layers.Rescaling(1./255, input_shape=(*img_size, 3)),
    
    layers.Conv2D(32, 3, activation='relu'),
    layers.MaxPooling2D(),
    
    layers.Conv2D(64, 3, activation='relu'),
    layers.MaxPooling2D(),
    
    layers.Conv2D(128, 3, activation='relu'),
    layers.MaxPooling2D(),
    
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(num_classes, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# d:\OTH Regensburg\SHK\Code\tf-env\lib\site-packages\keras\src\layers\preprocessing\tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ (None, 64, 64, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 62, 62, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 31, 31, 32)     │             0 │
# ...

# %% [markdown]
# ## Train and Evaluate

# %%
epochs = 10
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs
)
# Out:
# Epoch 1/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1010s 1s/step - accuracy: 0.9997 - loss: 0.0260 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 2/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1152s 2s/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 3/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 831s 1s/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 4/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 667s 881ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 5/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 428s 565ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 6/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 598s 790ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 7/10
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 366s 484ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# ...

# %% [markdown]
# Then evaluate its performance:

# %%
test_loss, test_acc = model.evaluate(val_ds)
print(f"Validation accuracy: {test_acc:.4f}")
# Out:
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 140s 725ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Validation accuracy: 1.0000

# %% [markdown]
# ## 5. Improvements & Next Steps
#
# Data Augmentation: Add RandomFlip, Rotation, Zoom, etc. to help generalize across handwriting variance.
#
# Residual Units & YOLO Detection: To replicate DIGITNET fully, you’d incorporate residual blocks and YOLO-style detection for multi-digit cases.
#
# Ensemble Voting: The DIGITNET-rec uses three CNNs and majority voting
# researchgate.net.
#
# Bounding Box / Multi-digit Subset: If you're working on multi-digit detection from the second subset, you'd implement object detection (e.g. using TensorFlow Object Detection API with YOLOv3/v4).
#
# Transfer Learning: Backbone models like ResNet or EfficientNet may boost recognition accuracy.
